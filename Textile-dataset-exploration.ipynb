# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Dataset: created from `Carbon Footprint of Textile and Clothing Products` and others data

# %%
fabriccomparison_df = pd.read_csv("data/fabrics-comparison.csv")

fabriccomparison_df
# Out:
#           fabric       type  co2_emissions (kg/kg Fiber)  \
# 0          Nylon  synthetic                           37
# 1        Acrylic  synthetic                           26
# 2      Polyester  synthetic                           19
# 3  Polypropylene  synthetic                           17
# 4        Viscose  synthetic                           15
# 5         Cotton    natural                            8
# 6           Wool    natural                            7
# 7           Hemp    natural                            3
#
#    energy_consumption (kW h/kg Fiber)  water_use (kg/kg fabric)
# 0                                  69                       465
# 1                                  49                       210
# 2                                  35                        20
# 3                                  32                        70
# 4                                  28                       390
# 5                                  15                      1850
# 6                                  13                        10
# 7                                   5                       210

# %%
#fabriccomparison_changed_df = pd.melt(fabriccomparison_df.drop(columns=['type']), id_vars="fabric", var_name="all_consumption", value_name="value")

fig, axes = plt.subplots(1, 3, figsize=(20, 5), sharex=False, sharey=False)
palette = "Spectral"

sns.barplot(ax=axes[0], data=fabriccomparison_df, x='fabric', y='co2_emissions (kg/kg Fiber)', palette=palette)
axes[0].set_title('Comparison of CO2 emissions per fabric')
axes[0].set_xlabel('')
axes[0].set_ylabel('CO2 emissions (in kg/kg Fiber)')
axes[0].set_xticklabels(fabriccomparison_df.fabric, rotation=90)

sns.barplot(ax=axes[1], data=fabriccomparison_df, x='fabric', y='energy_consumption (kW h/kg Fiber)', palette=palette)
axes[1].set_title('Comparison of energy consumption per fabric')
axes[1].set_xlabel('')
axes[1].set_ylabel('CO2 emissions (in kWh/kg Fiber)')
axes[1].set_xticklabels(fabriccomparison_df.fabric, rotation=90)

sns.barplot(ax=axes[2], data=fabriccomparison_df, x='fabric', y='water_use (kg/kg fabric)', palette=palette)
axes[2].set_title('Comparison of water used per fabric')
axes[2].set_xlabel('')
axes[2].set_ylabel('Water use (in kg/kg Fiber)')
axes[2].set_xticklabels(fabriccomparison_df.fabric, rotation=90)

plt.suptitle('The impact of different fabric production', fontsize=20,y=1.05)
plt.show()

# %% [markdown]
# ## Dataset: `Plastic based Textiles in clothing industry`

# %%
df = pd.read_csv("data/Plastic based Textiles in clothing industry.csv")

df
# Out:
#                Company     Product_Type  Production_Year  \
# 0                 Zara        Polyester             2020
# 1                 Zara            Nylon             2019
# 2                 Zara    Recycled_Poly             2021
# 3                 Zara           Cotton             2018
# 4                 Zara  Synthetic_Blend             2022
# ...                ...              ...              ...
# 6951            Adidas           Tencel             2018
# 6952  Urban Outfitters       Microfiber             2019
# 6953  Urban Outfitters   Organic_Cotton             2019
# 6954            Adidas       Microfiber             2020
# 6955  Urban Outfitters            Nylon             2020
#
#       Greenhouse_Gas_Emissions  Pollutants_Emitted  Water_Consumption  \
# 0                         5000                  20               7500
# 1                         3000                  15               5000
# 2                         3500                  18               6000
# 3                         2000                  10               4500
# 4                         6000                  25               8000
# ...                        ...                 ...                ...
# 6951                      3218                  21               7536
# 6952                      2622                  11               5267
# 6953                      5920                  24               4321
# 6954                      2897                  16               4125
# 6955                      3428                  25               7005
#
#       Energy_Consumption  Waste_Generation  Sales_Revenue
# 0                   1200               300         500000
# 1                    900               200         450000
# 2                   1100               250         480000
# 3                    800               180         550000
# 4                   1500               350         600000
# ...                  ...               ...            ...
# 6951                 902               192         523173
# 6952                 952               170         436096
# 6953                 982               177         489765
# 6954                1085               321         487443
# 6955                 906               336         552712
#
# [6956 rows x 9 columns]

# %%
all_companies = df.Company.unique()
print(f"There are {len(all_companies)} companies: {all_companies}")

all_years = df.sort_values(by='Production_Year').Production_Year.unique()
print(f"Spread out over {len(all_years)} years: {all_years}")
# Out:
# There are 5 companies: ['Zara' 'Adidas' 'Forever 21' 'Urban Outfitters' 'Nike']
# Spread out over 5 years: [2018 2019 2020 2021 2022]

# %%
df.groupby('Company').agg({
    'Product_Type' : ['nunique'],
    'Greenhouse_Gas_Emissions' : ['sum'],
    'Pollutants_Emitted' : ['sum'],
    'Water_Consumption' : ['sum'],
    'Energy_Consumption' : ['sum'],
    'Waste_Generation' : ['sum'],
    'Sales_Revenue' : ['sum']
    })
# Out:
#                  Product_Type Greenhouse_Gas_Emissions Pollutants_Emitted  \
#                       nunique                      sum                sum
# Company
# Adidas                     11                  5398561              23096
# Forever 21                 11                  5293637              22881
# Nike                       11                  5622829              24794
# Urban Outfitters           11                  5373217              23719
# Zara                       11                  5379307              23712
#
#                  Water_Consumption Energy_Consumption Waste_Generation  \
#                                sum                sum              sum
# Company
# Adidas                     8144954            1520380           345775
# Forever 21                 8064359            1497468           336146
# Nike                       8677384            1606703           358839
# Urban Outfitters           8357986            1526717           345631
# Zara                       8379830            1545930           344900
#
#                  Sales_Revenue
#                            sum
# Company
# Adidas               699566774
# Forever 21           689964263
# Nike                 737088156
# Urban Outfitters     710050520
# Zara                 712523829

# %%
product_type_info = df.groupby('Product_Type').agg({
    'Company' : ['nunique'],
    'Greenhouse_Gas_Emissions' : ['sum'],
    'Pollutants_Emitted' : ['sum'],
    'Water_Consumption' : ['sum'],
    'Energy_Consumption' : ['sum'],
    'Waste_Generation' : ['sum'],
    'Sales_Revenue' : ['sum']
    })

product_type_info
# Out:
#                 Company Greenhouse_Gas_Emissions Pollutants_Emitted  \
#                 nunique                      sum                sum
# Product_Type
# Cotton                5                  2417365              10496
# Linen                 5                  2639911              11699
# Microfiber            5                  2530315              11078
# Nylon                 5                  2471469              10802
# Organic_Cotton        5                  2604502              11449
# Polyester             5                  2595226              11284
# Recycled_Poly         5                  2389269              10826
# Synthetic_Blend       5                  2365048               9676
# Tencel                5                  2264282               9913
# Viscose               5                  2412672              10603
# Wool                  5                  2377492              10376
#
#                 Water_Consumption Energy_Consumption Waste_Generation  \
#                               sum                sum              sum
# Product_Type
# Cotton                    3636368             677462           154098
# Linen                     4058802             760197           169141
# Microfiber                3926062             713882           163308
# Nylon                     3822366             705878           159496
# Organic_Cotton            4034172             742718           168898
# Polyester                 3985025             736864           165035
# Recycled_Poly             3729576             700929           158447
# Synthetic_Blend           3515378             648776           144425
# Tencel                    3515887             638388           142010
# Viscose                   3745861             687358           154022
# Wool                      3655016             684746           152411
#
#                 Sales_Revenue
#                           sum
# Product_Type
# Cotton              314224128
# Linen               348922471
# Microfiber          331210557
# Nylon               323141583
# Organic_Cotton      343069881
# Polyester           341159309
# Recycled_Poly       321160499
# Synthetic_Blend     298031021
# Tencel              297356233
# Viscose             319822092
# Wool                311095768

# %%
product_type_info_melted = product_type_info.drop(columns=[('Sales_Revenue', 'sum'), ('Company', 'nunique')]).reset_index().melt(id_vars='Product_Type', var_name='Variable', value_name='Value')

plt.figure(figsize=(10, 6))
sns.barplot(x='Product_Type', y='Value', hue='Variable', data=product_type_info_melted, palette="Spectral")
plt.xlabel('Product Type')
plt.ylabel('Value')
plt.title('Comparison of emissions per product type')
plt.legend(title='Variable')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Dataset: `Environmental Performance of UK Fashion Brands`

# %%
df2 = pd.read_excel("data/Environmental Performance of UK Fashion Brands.xlsx")

df2 = df2.set_index('Brand')

df2
# Out:
#                    Sourcing sustainable materials (%)  \
# Brand
# ASOS                                               65
# Boohoo                                             50
# Next                                               70
# M&S                                                80
# Primark                                            45
# ...                                               ...
# Hobbs                                              70
# Holland & Barrett                                  65
# House of Fraser                                    50
# Jaeger                                             70
# Jigsaw                                             75
#
#                    Ethical labor practices (1-5)  \
# Brand
# ASOS                                           4
# Boohoo                                         3
# Next                                           4
# M&S                                            5
# Primark                                        3
# ...                                          ...
# Hobbs                                          4
# Holland & Barrett                              4
# House of Fraser                                3
# Jaeger                                         4
# Jigsaw                                         5
#
#                    Responsible production processes (1-5)  \
# Brand
# ASOS                                                    4
# Boohoo                                                  3
# Next                                                    4
# M&S                                                     5
# Primark                                                 3
# ...                                                   ...
# Hobbs                                                   4
# Holland & Barrett                                       4
# House of Fraser                                         3
# Jaeger                                                  4
# Jigsaw                                                  5
#
#                    Eco-efficient distribution and logistics practices (1-5)  \
# Brand
# ASOS                                                               4
# Boohoo                                                             3
# Next                                                               4
# M&S                                                                5
# Primark                                                            3
# ...                                                              ...
# Hobbs                                                              4
# Holland & Barrett                                                  4
# House of Fraser                                                    3
# Jaeger                                                             4
# Jigsaw                                                             5
#
#                    Carbon emissions (kg CO2e per ton of product)  \
# Brand
# ASOS                                                         5.5
# Boohoo                                                       6.0
# Next                                                         5.0
# M&S                                                          4.0
# Primark                                                      6.5
# ...                                                          ...
# Hobbs                                                        5.0
# Holland & Barrett                                            5.5
# House of Fraser                                              6.0
# Jaeger                                                       5.0
# Jigsaw                                                       4.5
#
#                    Water use (m3 per ton of product)  \
# Brand
# ASOS                                              18
# Boohoo                                            20
# Next                                              16
# M&S                                               14
# Primark                                           22
# ...                                              ...
# Hobbs                                             16
# Holland & Barrett                                 18
# House of Fraser                                   20
# Jaeger                                            16
# Jigsaw                                            15
#
#                    Waste generation (kg per ton of product)  \
# Brand
# ASOS                                                      4
# Boohoo                                                    5
# Next                                                      3
# M&S                                                       2
# Primark                                                   5
# ...                                                     ...
# Hobbs                                                     3
# Holland & Barrett                                         4
# House of Fraser                                           5
# Jaeger                                                    3
# Jigsaw                                                    3
#
#                    Environmental performance score (0-100)
# Brand
# ASOS                                                    82
# Boohoo                                                  75
# Next                                                    86
# M&S                                                     93
# Primark                                                 72
# ...                                                    ...
# Hobbs                                                   86
# Holland & Barrett                                       82
# House of Fraser                                         75
# Jaeger                                                  86
# Jigsaw                                                  87
#
# [100 rows x 8 columns]

# %%
normalized_df2=(df2-df2.min())/(df2.max()-df2.min())

plt.figure(figsize=(20, 5))
sns.lineplot(data=normalized_df2.sort_values(by='Carbon emissions (kg CO2e per ton of product)'), palette="Spectral")
plt.legend(bbox_to_anchor=(1, 1.05), loc=2, borderaxespad=1.)
plt.xlabel('Brand')
plt.ylabel('Sourcing sustainable materials (%)')
plt.xticks(rotation=90)
plt.show()
